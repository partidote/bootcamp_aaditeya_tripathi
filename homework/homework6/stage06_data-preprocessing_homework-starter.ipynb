# %% [markdown]
# # Setup: Generate Sample Dataset
#
# This cell creates the required folder structure (`data/raw/` and `data/processed/`) relative to the notebook, and generates the sample CSV dataset with missing values.
# This ensures the dataset is ready for cleaning functions and saves it to `data/raw/sample_data.csv`.

# %%
# --- packages this notebook needs (uncomment and run once, then re-comment) ---
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in /Users/aaditeya/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: pandas in /Users/aaditeya/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/aaditeya/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aaditeya/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/aaditeya/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/aaditeya/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /Users/aaditeya/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# --- files this notebook needs (run me first - I only report, I change nothing) ---
from pathlib import Path

ROOT = Path.cwd()          # notebooks are meant to be run from their own folder
CHECKS = [
    ("src/cleaning.py", "NEEDED", "YOU write this in the homework - the import fails until you do"),
]

print(f"Looking in: {ROOT}\n")
missing = 0
for rel, kind, note in CHECKS:
    here = (ROOT / rel).exists()
    if not here and kind == "NEEDED":
        missing += 1
    print(f"  [{'OK ' if here else 'MISS'}]  {kind:<8}  {rel:<34}  {note}")

if missing:
    print(f"\n{missing} needed file(s) missing. Put them at the paths above, relative to:\n  {ROOT}")
    print("If that folder looks wrong, you are running the notebook from the wrong place.")
else:
    print("\nAll needed files present.")
# Out:
# Looking in: /Users/aaditeya/Desktop/bootcamp_aaditeya_tripathi/homework/homework6
#
#   [OK ]  NEEDED    src/cleaning.py                     YOU write this in the homework - the import fails until you do
#
# All needed files present.

# %%
import os
import pandas as pd
import numpy as np

# Define folder paths relative to this notebook
raw_dir = 'data/raw'
processed_dir = 'data/processed'

# Create folders if they don't exist
os.makedirs(raw_dir, exist_ok=True)
os.makedirs(processed_dir, exist_ok=True)

# Define the sample data
data = {
    'age': [34, 45, 29, 50, 38, np.nan, 41],
    'income': [55000, np.nan, 42000, 58000, np.nan, np.nan, 49000],
    'score': [0.82, 0.91, np.nan, 0.76, 0.88, 0.65, 0.79],
    'zipcode': ['90210', '10001', '60614', '94103', '73301', '12345', '94105'],
    'city': ['Beverly', 'New York', 'Chicago', 'SF', 'Austin', 'Unknown', 'San Francisco'],
    'extra_data': [np.nan, 42, np.nan, np.nan, np.nan, 5, np.nan]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV in raw data folder
csv_path = os.path.join(raw_dir, 'sample_data.csv')
if not os.path.exists(csv_path):
    df.to_csv(csv_path, index=False)
    print(f'Sample dataset created and saved to {csv_path}')
else:
    print(f'File already exists at {csv_path}. Skipping CSV creation to avoid overwrite.')
# Out:
# Sample dataset created and saved to data/raw/sample_data.csv

# %% [markdown]
# # Homework Starter — Stage 6: Data Preprocessing
# Use this notebook to apply your cleaning functions and save processed data.

# %%
import pandas as pd

# Uncomment once you have written src/cleaning.py (see the homework sheet).
# Until then this import fails - the module is yours to create.
from src import cleaning

# %% [markdown]
# ## Load Raw Dataset

# %%
df = pd.read_csv('data/raw/sample_data.csv')
df.head()
# Out:
#     age   income  score  zipcode      city  extra_data
# 0  34.0  55000.0   0.82    90210   Beverly         NaN
# 1  45.0      NaN   0.91    10001  New York        42.0
# 2  29.0  42000.0    NaN    60614   Chicago         NaN
# 3  50.0  58000.0   0.76    94103        SF         NaN
# 4  38.0      NaN   0.88    73301    Austin         NaN

# %% [markdown]
# ## Apply Cleaning Functions

# %%
# Fill missing numeric features with median (MCAR/MAR assumption)
df_clean = cleaning.fill_missing_median(df, ['age', 'income', 'score'])

# Drop columns/rows with high missingness threshold
df_clean = cleaning.drop_missing(df_clean, threshold=0.7)

# Normalize continuous numeric columns using MinMaxScaler [0, 1]
df_clean = cleaning.normalize_data(df_clean, ['age', 'income', 'score'], method='minmax')

# Compare Original vs Cleaned Data
print("--- Original Data Missing Counts ---")
print(df.isna().sum())
print("\n--- Cleaned Data Missing Counts ---")
print(df_clean.isna().sum())

print("\n--- Cleaned Data Preview ---")
display(df_clean.head(7))
# Out:
# --- Original Data Missing Counts ---
# age           1
# income        3
# score         1
# zipcode       0
# city          0
# extra_data    5
# dtype: int64
#
# --- Cleaned Data Missing Counts ---
# age           0
# income        0
# score         0
# zipcode       0
# city          0
# extra_data    5
# dtype: int64
#
# --- Cleaned Data Preview ---
#         age  income     score  zipcode           city  extra_data
# 0  0.238095  0.8125  0.653846    90210        Beverly         NaN
# 1  0.761905  0.6250  1.000000    10001       New York        42.0
# 2  0.000000  0.0000  0.596154    60614        Chicago         NaN
# 3  1.000000  1.0000  0.423077    94103             SF         NaN
# 4  0.428571  0.6250  0.884615    73301         Austin         NaN
# 5  0.500000  0.6250  0.000000    12345        Unknown         5.0
# 6  0.571429  0.4375  0.538462    94105  San Francisco         NaN

# %% [markdown]
# ## Save Cleaned Dataset

# %%
df.to_csv('data/processed/sample_data_cleaned.csv', index=False)
